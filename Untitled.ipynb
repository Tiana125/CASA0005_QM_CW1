# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sms
import statsmodels.formula.api as smf
import scipy.stats as sps

from sklearn.preprocessing import PolynomialFeatures


import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
all_data = pd.read_csv('coursework_1_data_2019.csv')
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   local_authority_area  152 non-null    object
#  1   2008_cases_total      152 non-null    int64
#  2   2013_cases_total      152 non-null    int64
#  3   2018_cases_total      152 non-null    int64
#  4   2008_pop_total        152 non-null    int64
#  5   2013_pop_total        152 non-null    int64
#  6   2018_pop_total        152 non-null    int64
#  7   2008_cases_male       152 non-null    int64
#  8   2013_cases_male       152 non-null    int64
#  9   2018_cases_male       152 non-null    int64
#  10  2008_pop_male         152 non-null    int64
#  11  2013_pop_male         152 non-null    int64
#  12  2018_pop_male         152 non-null    int64
#  13  2008_cases_female     152 non-null    int64
#  14  2013_cases_female     152 non-null    int64
#  15  2018_cases_female     152 non-null    int64
#  16  2008_pop_female       152 non-null    int64
#  17  2013_pop_female       152 non-null    int64
#  18  2018_pop_female       152 non-null    int64
#  19  total_budget          152 non-null    int64
#  20  clean_air             152 non-null    int64
#  21  clean_environ         152 non-null    int64
#  22  health_training       152 non-null    int64
#  23  school_awareness      152 non-null    int64
#  24  media_awareness       152 non-null    int64
#  25  sub_counselling       152 non-null    int64
#  26  region                152 non-null    object
#  27  local_authority_type  152 non-null    object
# dtypes: int64(25), object(3)
# memory usage: 33.4+ KB

# %%
#all_data.groupby(by='region')['local_authority_area'].sum()
#em_data = all_data[all_data['region'=='East Midlands']]
#em_data

london_data = all_data.loc[all_data['region']=='London']

london_data.insert(5, 'cases_08_per1k',value = 1000*london_data['2008_cases_total']/london_data['2008_pop_total'])
london_data.insert(6, 'cases_13_per1k',value = 1000*london_data['2013_cases_total']/london_data['2013_pop_total'])
london_data.insert(7, 'cases_18_per1k',value = 1000*london_data['2018_cases_total']/london_data['2018_pop_total'])



#london_data = london_data.drop(['2008_cases_total','2013_cases_total','2018_cases_total',
#                                '2008_pop_total','2013_pop_total','2018_pop_total'],axis=1)

london_data = london_data.drop(['2008_cases_male','2013_cases_male','2018_cases_male',
                                '2008_cases_female','2013_cases_female','2018_cases_female',
                                '2008_pop_male','2013_pop_male','2018_pop_male',
                                '2008_pop_female','2013_pop_female','2018_pop_female',
                               'region','local_authority_type'],axis=1)

london_data.insert(4,'increase_percent',
                   value = 100*(london_data['cases_18_per1k']-london_data['cases_08_per1k'])/london_data['cases_08_per1k'])

london_data.insert(5, 'clean_air_p',value = 100*london_data['clean_air']/london_data['total_budget'])
london_data.insert(6, 'clean_environ_p',value = 100*london_data['clean_environ']/london_data['total_budget'])
london_data.insert(7, 'health_training_p',value = 100*london_data['school_awareness']/london_data['total_budget'])
london_data.insert(8, 'school_awareness_p',value = 100*london_data['media_awareness']/london_data['total_budget'])
london_data.insert(9, 'media_awareness_p',value = 100*london_data['sub_counselling']/london_data['total_budget'])
london_data.insert(10, 'sub_counselling_p',value = 100*london_data['health_training']/london_data['total_budget'])

london_data = london_data.drop(['clean_air','clean_environ','school_awareness',
                                'media_awareness','sub_counselling','health_training'],axis=1)
print(london_data[['2018_pop_total']].mean())
##########
london_data = london_data.drop(25)
##########

london_data['rank'] = london_data['increase_percent'].rank() #higher indicates worse performance

london_data.head()
#london_data.loc[london_data.increase_percent.idxmax()]
#london_data.loc[london_data.increase_percent.idxmin()]
# Out:
# 2018_pop_total                               235,201.6061
# dtype: float64
#     local_authority_area  2008_cases_total  2013_cases_total  \
# 0   Barking and Dagenham               593               619
# 1                 Barnet               539               594
# 5                 Bexley               519               601
# 13                 Brent               933              1074
# 16               Bromley               611               737
#
#     2018_cases_total                         increase_percent  \
# 0                763                                  22.2301
# 1                773                                  37.1607
# 5                707                                  25.5164
# 13              1209                                  12.8768
# 16               935                                  40.8987
#
#                                 clean_air_p  \
# 0                                   15.1079
# 1                                   22.7273
# 5                                   36.1809
# 13                                  17.5732
# 16                                  11.0345
#
#                             clean_environ_p  \
# 0                                   15.8273
# 1                                    7.7273
# 5                                   13.5678
# 13                                  30.1255
# 16                                  27.5862
#
#                           health_training_p  \
# 0                                   29.4964
# 1                                   33.6364
# 5                                   32.1608
# 13                                  20.0837
# 16                                  21.7241
#
#                          school_awareness_p  \
# 0                                   12.9496
# 1                                   13.6364
# 5                                    7.5377
# 13                                  16.3180
# 16                                  20.3448
#
#                           media_awareness_p  \
# 0                                   13.6691
# 1                                   11.8182
# 5                                    3.5176
# 13                                   6.6946
# 16                                  11.7241
#
#                           sub_counselling_p  2008_pop_total  \
# 0                                   12.9496          172684
# 1                                   10.4545          340435
# 5                                    7.0352          226554
# 13                                   9.2050          256258
# 16                                   7.5862          310127
#
#                              cases_08_per1k  \
# 0                                    3.4340
# 1                                    1.5833
# 5                                    2.2908
# 13                                   3.6409
# 16                                   1.9702
#
#                              cases_13_per1k  \
# 0                                    3.4575
# 1                                    1.7264
# 5                                    2.4760
# 13                                   3.9073
# 16                                   2.2910
#
#                              cases_18_per1k  2013_pop_total  2018_pop_total  \
# 0                                    4.1974          179030          181779
# 1                                    2.1716          344062          355955
# 5                                    2.8754          242730          245880
# 13                                   4.1097          274867          294183
# 16                                   2.7759          321687          336824
#
#     total_budget                                     rank
# 0         139000                                   7.0000
# 1         220000                                  26.0000
# 5         199000                                  12.0000
# 13        239000                                   2.0000
# 16        290000                                  28.0000

# %%
fig = plt.figure()

plt.subplot(2, 3, 1)
plt.scatter(london_data['clean_air_p'],london_data['rank'])

plt.subplot(2, 3, 2)
plt.scatter(london_data['clean_environ_p'],london_data['rank'])

plt.subplot(2, 3, 3)
plt.scatter(london_data['health_training_p'],london_data['rank'])

plt.subplot(2, 3, 4)
plt.scatter(london_data['school_awareness_p'],london_data['rank'])

plt.subplot(2, 3, 5)
plt.scatter(london_data['media_awareness_p'],london_data['rank'])

plt.subplot(2, 3, 6)
plt.scatter(london_data['sub_counselling_p'],london_data['rank'])


plt.show()

# %%
X =  london_data['2018_cases_total']
Y =  london_data['total_budget']
print(sps.pearsonr(X,Y))

X =  np.log(london_data['2018_cases_total'])
Y =  np.log(london_data['total_budget'])
print(sps.pearsonr(X,Y))

plt.xlabel('2018_cases_total ')
plt.ylabel('total_budget')
a = plt.plot(X,Y,'.', label='original data')

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 
b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# (0.7092914297715339, 5.501651170559782e-06)
# (0.7248428480979372, 2.7097685036166646e-06)
# y = 0.437 x + 9.288
# Rsq =  0.5253971544387291
# p-value =  2.7097685036166748e-06

# %%
X =  london_data['2018_pop_total']
Y =  london_data['total_budget']
print(sps.pearsonr(X,Y))

X =  np.log(london_data['2018_pop_total'])
Y =  np.log(london_data['total_budget'])
print(sps.pearsonr(X,Y))

plt.xlabel('2018_pop_total ')
plt.ylabel('total_budget')
a = plt.plot(X,Y,'.', label='original data')

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 
b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# (0.8202924048361341, 9.120677262669191e-09)
# (0.8568272019211896, 3.904420191592574e-10)
# y = 0.768 x + 2.644
# Rsq =  0.7341528539520952
# p-value =  3.904420191592521e-10

# %%
X =  np.log(london_data['total_budget'])
Yp =  np.log(london_data['2018_pop_total'])
print(sps.pearsonr(X,Yp))

Yc =  np.log(london_data['2018_cases_total'])
print(sps.pearsonr(X,Yc))

Yper=np.log(london_data['2018_cases_total'])/np.log(london_data['2018_pop_total'])
print(sps.pearsonr(X,Yper))

plt.xlabel('total_budget ')
#plt.ylabel('2018_pop_total')
#a = plt.plot(X,Yp,'.', label='2018_pop_total')
#b = plt.plot(X,Yc,'.', label='2018_cases_total')
c = plt.plot(X,Yper,'.', label='cases per pop')

#slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yc) 
#slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yc) 
slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yper) 
f = plt.plot(X, X*slope + intercept, 'r', label = 'cases per pop line') # Plot the regression line.

plt.ylim(0,0.6)
plt.legend()
plt.show()
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# (0.8568272019211896, 3.904420191592574e-10)
# (0.7248428480979372, 2.7097685036166646e-06)
# (0.5356106944808208, 0.0015822819356381835)
# y = 0.057 x + -0.159
# Rsq =  0.28687881604222676
# p-value =  0.0015822819356381952

# %%
X =  np.log(london_data['total_budget'])
Yper=np.log(london_data['2018_cases_total'])/np.log(london_data['2018_pop_total'])

plt.xlabel('total_budget ')
plt.ylabel('2018 cases per 100 people')

from sklearn import linear_model
ransac = linear_model.RANSACRegressor()
ran = ransac.fit(np.array(X).reshape(-1, 1), np.array(Yper).reshape(-1, 1), threshold )
Yper_ransac = ransac.predict(np.array(X).reshape(-1, 1))
plt.plot(X, Yper_ransac, color='g', label='RANSAC regressor')
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)
param=ransac.get_params()
#c = plt.plot(X,Yper,'.', label='cases per pop data')
plt.scatter(X[inlier_mask], Yper[inlier_mask], color='yellowgreen', marker='.',
            label='Inliers')
plt.scatter(X[outlier_mask], Yper[outlier_mask], color='r', marker='.',
            label='Outliers')

#slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yper) 
#f = plt.plot(X, X*slope + intercept, 'r', label = 'cases per pop line') # Plot the regression line.
f, res, _, _, _ = np.polyfit(X,Yper,1, full=True)
poly = np.poly1d(f)

new_X= np.array(np.sort(X.values))

new_x = np.linspace(new_X[0], new_X[-1])
new_Y=poly(new_x)
plt.plot(new_x,new_Y)
#Ypred_ransac = X.multiply(0.0179566)+0.309245

plt.legend()
plt.show()
#print(res)
print('ransac',ransac.estimator_.coef_, 'and', ransac.estimator_.intercept_)
#print("y =", round(slope,3), "x +", round(intercept,3))
print("polyfit Rsq = ", sklearn.metrics.r2_score(Yper, poly(X)))
print("ransac Rsq = ", sklearn.metrics.r2_score(Yper, Yper_ransac))
print("p-value = ", p_value)
# Out:
# ransac [[0.02099789]] and [0.2741155]
# polyfit Rsq =  0.286878816042227
# ransac Rsq =  0.1721068492884974
# p-value =  0.0015264757791837835

# %%
#######standardisd
#print(london_data['total_budget'])
X =  np.log((london_data['total_budget'])-np.mean(london_data['total_budget'])/np.std(london_data['total_budget']))
Yp =  np.log((london_data['2018_pop_total'])-np.mean(london_data['2018_pop_total'])/np.std(london_data['2018_pop_total']))
#print(sps.pearsonr(X,Yp))

Yc =  np.log((london_data['2018_cases_total'])-np.mean(london_data['2018_cases_total'])/np.std(london_data['2018_cases_total']))
#print(sps.pearsonr(X,Yc))

Yper=Yc/Yp
#print(sps.pearsonr(X,Yper))


plt.xlabel('total_budget ')
#plt.ylabel('2018_pop_total')
a = plt.plot(X,Yp,'.', label='2018_pop_total')
b = plt.plot(X,Yc,'.', label='2018_cases_total')
c = plt.plot(X,Yper,'.', label='cases per pop')


slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yp) 
d = plt.plot(X, X*slope + intercept, 'r', label = 'pop line') 
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yc) 
e = plt.plot(X, X*slope + intercept, 'g', label = 'cases line') 
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
slope, intercept, r_value, p_value, std_err = sps.linregress(X, Yper) 
f = plt.plot(X, X*slope + intercept, 'b', label = 'cases per pop line') 
print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)

#plt.ylim(0,0.6)
plt.legend()
plt.show()
# Out:
# y = 0.956 x + 0.761
# Rsq =  0.7341539310886502
# p-value =  3.9041802722195216e-10
# y = 1.208 x + -8.135
# Rsq =  0.5254249197829899
# p-value =  2.707327588952491e-06
# y = 0.057 x + -0.165
# Rsq =  0.2884738824753271
# p-value =  0.0015264757791837835

# %%
london_data_log = np.log(london_data.drop('local_authority_area',axis=1))

model_areas = sms.formula.ols('cases_08_per1k ~ clean_air_p+clean_environ_p + health_training_p + school_awareness_p+media_awareness_p+sub_counselling_p', london_data).fit()
model_areas.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         cases_08_per1k   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                 -0.114
# Method:                 Least Squares   F-statistic:                    0.3637
# Date:                Fri, 13 Nov 2020   Prob (F-statistic):              0.869
# Time:                        09:06:28   Log-Likelihood:                -34.279
# No. Observations:                  32   AIC:                             80.56
# Df Residuals:                      26   BIC:                             89.35
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0014      0.000      3.620      0.001       0.001       0.002
# clean_air_p            0.0010      0.019      0.050      0.960      -0.039       0.041
# clean_environ_p        0.0328      0.013      2.557      0.017       0.006       0.059
# health_training_p      0.0319      0.021      1.500      0.146      -0.012       0.076
# school_awareness_p     0.0244      0.024      1.005      0.324      -0.025       0.074
# media_awareness_p      0.0209      0.045      0.460      0.649      -0.073       0.114
# sub_counselling_p      0.0294      0.043      0.685      0.500      -0.059       0.118
# ==============================================================================
# Omnibus:                        2.466   Durbin-Watson:                   1.799
# Prob(Omnibus):                  0.291   Jarque-Bera (JB):                2.145
# Skew:                           0.613   Prob(JB):                        0.342
# Kurtosis:                       2.673   Cond. No.                     2.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.57e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# correlation of independent variables to y

# %%
#plt.rcParams["axes.grid"] = False
#f = plt.figure(figsize=(19, 15))
#plt.matshow(london_data.corr(), fignum=f.number)
#plt.xticks(range(london_data.shape[1]), london_data.columns, fontsize=14, rotation=45)
#plt.yticks(range(london_data.shape[1]), london_data.columns, fontsize=14)
#cb = plt.colorbar()
#cb.ax.tick_params(labelsize=14)
#plt.title('Correlation Matrix', fontsize=16)

import seaborn as sns
plt.figure(figsize=(12,10))
cor = london_data.drop(['local_authority_area','cases_08_per1k','cases_13_per1k','cases_18_per1k'
                 ],axis = 1).corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
plt.figure(figsize=(12,10))
cor = np.log(london_data.drop(['local_authority_area','cases_08_per1k','cases_13_per1k','cases_18_per1k'
                 ],axis = 1)).corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
london_data_numeric=pd.get_dummies(london_data)
#london_data_numeric.info()
london_data_numeric=london_data_numeric.drop('local_authority_area_City of London',axis=1)

plt.plot(london_data_numeric[['oeight_cases_per1k']],london_data_numeric[['local_authority_area_Barking and Dagenham']])

model_dum = sms.OLS(endog=london_data_numeric[['oeight_cases_per1k']], exog=sms.add_constant(london_data_numeric.drop(['total_budget',
                                                                                                                 'clean_air'],
                                                                                                               axis=1))).fit()
model_dum.summary()

#plt.scatter(model_dum.fittedvalues, model_dum.resid)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 143
# Data columns (total 44 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   oeight_cases_per1k                           33 non-null     float64
#  1   13_cases_per1k                               33 non-null     float64
#  2   18_cases_per1k                               33 non-null     float64
#  3   increase_percent                             33 non-null     float64
#  4   total_budget                                 33 non-null     int64
#  5   clean_air                                    33 non-null     int64
#  6   clean_environ                                33 non-null     int64
#  7   health_training                              33 non-null     int64
#  8   school_awareness                             33 non-null     int64
#  9   media_awareness                              33 non-null     int64
#  10  sub_counselling                              33 non-null     int64
#  11  local_authority_area_Barking and Dagenham    33 non-null     uint8
#  12  local_authority_area_Barnet                  33 non-null     uint8
#  13  local_authority_area_Bexley                  33 non-null     uint8
#  14  local_authority_area_Brent                   33 non-null     uint8
#  15  local_authority_area_Bromley                 33 non-null     uint8
#  16  local_authority_area_Camden                  33 non-null     uint8
#  17  local_authority_area_City of London          33 non-null     uint8
#  18  local_authority_area_Croydon                 33 non-null     uint8
#  19  local_authority_area_Ealing                  33 non-null     uint8
#  20  local_authority_area_Enfield                 33 non-null     uint8
#  21  local_authority_area_Greenwich               33 non-null     uint8
#  22  local_authority_area_Hackney                 33 non-null     uint8
#  23  local_authority_area_Hammersmith and Fulham  33 non-null     uint8
#  24  local_authority_area_Haringey                33 non-null     uint8
#  25  local_authority_area_Harrow                  33 non-null     uint8
#  26  local_authority_area_Havering                33 non-null     uint8
#  27  local_authority_area_Hillingdon              33 non-null     uint8
#  28  local_authority_area_Hounslow                33 non-null     uint8
#  29  local_authority_area_Islington               33 non-null     uint8
#  30  local_authority_area_Kensington and Chelsea  33 non-null     uint8
#  31  local_authority_area_Kingston upon Thames    33 non-null     uint8
#  32  local_authority_area_Lambeth                 33 non-null     uint8
#  33  local_authority_area_Lewisham                33 non-null     uint8
#  34  local_authority_area_Merton                  33 non-null     uint8
#  35  local_authority_area_Newham                  33 non-null     uint8
#  36  local_authority_area_Redbridge               33 non-null     uint8
#  37  local_authority_area_Richmond upon Thames    33 non-null     uint8
#  38  local_authority_area_Southwark               33 non-null     uint8
#  39  local_authority_area_Sutton                  33 non-null     uint8
#  40  local_authority_area_Tower Hamlets           33 non-null     uint8
#  41  local_authority_area_Waltham Forest          33 non-null     uint8
#  42  local_authority_area_Wandsworth              33 non-null     uint8
#  43  local_authority_area_Westminster             33 non-null     uint8
# dtypes: float64(4), int64(7), uint8(33)
# memory usage: 4.2 KB
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1729: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     oeight_cases_per1k   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):                nan
# Time:                        13:41:50   Log-Likelihood:                 812.74
# No. Observations:                  33   AIC:                            -1559.
# Df Residuals:                       0   BIC:                            -1510.
# Df Model:                          32
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.1160        inf          0        nan         nan         nan
# oeight_cases_per1k                              0.3334        inf          0        nan         nan         nan
# 13_cases_per1k                                  0.2492        inf          0        nan         nan         nan
# 18_cases_per1k                                  0.3298        inf          0        nan         nan         nan
# increase_percent                               -0.0058        inf         -0        nan         nan         nan
# clean_environ                               -9.703e-08        inf         -0        nan         nan         nan
# health_training                              1.868e-06        inf          0        nan         nan         nan
# school_awareness                             5.286e-08        inf          0        nan         nan         nan
# media_awareness                             -3.193e-07        inf         -0        nan         nan         nan
# sub_counselling                              -1.57e-06        inf         -0        nan         nan         nan
# local_authority_area_Barking and Dagenham       0.0587        inf          0        nan         nan         nan
# local_authority_area_Barnet                     0.0151        inf          0        nan         nan         nan
# local_authority_area_Bexley                    -0.0165        inf         -0        nan         nan         nan
# local_authority_area_Brent                      0.0577        inf          0        nan         nan         nan
# local_authority_area_Bromley                   -0.0149        inf         -0        nan         nan         nan
# local_authority_area_Camden                     0.0082        inf          0        nan         nan         nan
# local_authority_area_Croydon                   -0.0219        inf         -0        nan         nan         nan
# local_authority_area_Ealing                     0.0012        inf          0        nan         nan         nan
# local_authority_area_Enfield                   -0.0116        inf         -0        nan         nan         nan
# local_authority_area_Greenwich                 -0.0365        inf         -0        nan         nan         nan
# local_authority_area_Hackney                   -0.0168        inf         -0        nan         nan         nan
# local_authority_area_Hammersmith and Fulham     0.0708        inf          0        nan         nan         nan
# local_authority_area_Haringey                  -0.0378        inf         -0        nan         nan         nan
# local_authority_area_Harrow                     0.0393        inf          0        nan         nan         nan
# local_authority_area_Havering                   0.0144        inf          0        nan         nan         nan
# local_authority_area_Hillingdon                -0.0642        inf         -0        nan         nan         nan
# local_authority_area_Hounslow                   0.0106        inf          0        nan         nan         nan
# local_authority_area_Islington                 -0.0175        inf         -0        nan         nan         nan
# local_authority_area_Kensington and Chelsea     0.0074        inf          0        nan         nan         nan
# local_authority_area_Kingston upon Thames       0.0367        inf          0        nan         nan         nan
# local_authority_area_Lambeth                    0.0075        inf          0        nan         nan         nan
# local_authority_area_Lewisham                  -0.0064        inf         -0        nan         nan         nan
# local_authority_area_Merton                     0.0230        inf          0        nan         nan         nan
# local_authority_area_Newham                    -0.0793        inf         -0        nan         nan         nan
# local_authority_area_Redbridge                  0.0330        inf          0        nan         nan         nan
# local_authority_area_Richmond upon Thames       0.0322        inf          0        nan         nan         nan
# local_authority_area_Southwark                 -0.0062        inf         -0        nan         nan         nan
# local_authority_area_Sutton                    -0.0567        inf         -0        nan         nan         nan
# local_authority_area_Tower Hamlets              0.0035        inf          0        nan         nan         nan
# local_authority_area_Waltham Forest            -0.0215        inf         -0        nan         nan         nan
# local_authority_area_Wandsworth                 0.0252        inf          0        nan         nan         nan
# local_authority_area_Westminster               -0.0227        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                       13.641   Durbin-Watson:                   0.575
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.424
# Skew:                          -1.105   Prob(JB):                     0.000271
# Kurtosis:                       5.657   Cond. No.                     8.19e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 8.19e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# rela btw total_budget and increase_percent
#
# No linear relationship
#
# Is there polynomial relation?

# %%
poly_features = PolynomialFeatures(degree=2)

x_train_poly = poly_features.fit_transform(london_data[['clean_air','clean_environ','school_awareness',
                                                'media_awareness','sub_counselling','health_training']])
#print(x_train_poly)
#X_grid_poly = poly_features.fit_transform(X_grid)

lin_reg = LinearRegression()
lin_reg.fit(x_train_poly, np.array(london_data[['increase_percent']]))

y_grid_pred = lin_reg.predict(x_train_poly)
# PLEASE DO NOT CHAN

fig, ax = plt.subplots()
ax.scatter(poly_variables, np.array(london_data[['increase_percent']]), c='r', marker='.', label="Training data")
ax.legend()
plt.plot(poly_variables, y_grid_pred)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-12e37fcbf099> in <module>
#      13
#      14 fig, ax = plt.subplots()
# ---> 15 ax.scatter(poly_variables, np.array(london_data[['increase_percent']]), c='r', marker='.', label="Training data")
#      16 ax.legend()
#      17 plt.plot(poly_variables, y_grid_pred)
#
# NameError: name 'poly_variables' is not defined

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.model_selection import train_test_split

poly = PolynomialFeatures(degree=2)
poly_variables = poly.fit_transform(london_data[['clean_air','clean_environ','school_awareness',
                                                'media_awareness','sub_counselling','health_training']])

poly_var_train, poly_var_test, res_train, res_test = train_test_split(poly_variables, london_data[['increase_percent']], test_size = 0.3, random_state = 4)

regression = linear_model.LinearRegression()

model = regression.fit(poly_var_train, res_train)
score = model.score(poly_var_test, res_test)

# %% [markdown]
# ### Simple linear regression

# %%
d1=london_data

# This performs a multiple regression of wellbeing against greenery and natural light:
multi_regression_model_1 = smf.ols(formula='increase_percent ~ health_training_p + media_awareness_p + clean_environ_p + school_awareness_p + sub_counselling_p',data=d1).fit()

# And this gives a big summary of the results:
print(multi_regression_model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       increase_percent   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     1.645
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):              0.182
# Time:                        08:25:55   Log-Likelihood:                -47.329
# No. Observations:                  33   AIC:                             106.7
# Df Residuals:                      27   BIC:                             115.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.1554      2.750      1.874      0.072      -0.488      10.799
# health_training_p     -0.0912      0.050     -1.818      0.080      -0.194       0.012
# media_awareness_p      0.0634      0.059      1.079      0.290      -0.057       0.184
# clean_environ_p       -0.0263      0.038     -0.693      0.494      -0.104       0.052
# school_awareness_p     0.0084      0.049      0.171      0.865      -0.092       0.109
# sub_counselling_p      0.0129      0.066      0.195      0.847      -0.123       0.148
# ==============================================================================
# Omnibus:                       12.797   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.939
# Skew:                           0.995   Prob(JB):                     0.000346
# Kurtosis:                       5.763   Cond. No.                         558.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Pick out some values of interest and print the regression equation:

beta_0, beta_1, beta_2 = multi_regression_model_1.params
rsq                    = multi_regression_model_1.rsquared
pval_0, pval_1, pval_2 = multi_regression_model_1.pvalues

print("y =", round(beta_1,3), "x1 +", round(beta_2,3), "x2 +", round(beta_0,3))
print("R^2     = ", rsq)
print("p-value_1 = ", round(pval_1,3))
print("p-value_2 = ", round(pval_2,3))
# Out:
# y = -0.93 x1 + -0.296 x2 + 51.039
# R^2     =  0.5519096548486597
# p-value_1 =  0.0
# p-value_2 =  0.381

# %%
fig = plt.figure(figsize=(10,8))
fig = sms.graphics.plot_regress_exog(multi_regression_model_1, 'health_training_p', fig=fig)

# %%
plt.scatter(london_data[['clean_air_p']],london_data[['increase_percent']])

# %%
# calculating VIF
# This function is partially from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constant item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
#df_predictors_selected_VIF = drop_column_using_vif_(bike_rental_final.drop('cnt', axis=1))
# Out:
#     local_authority_area                       oeight_cases_per1k  \
# 0   Barking and Dagenham                                   3.4340
# 1                 Barnet                                   1.5833
# 5                 Bexley                                   2.2908
# 13                 Brent                                   3.6409
# 16               Bromley                                   1.9702
#
#                              13_cases_per1k  \
# 0                                    3.4575
# 1                                    1.7264
# 5                                    2.4760
# 13                                   3.9073
# 16                                   2.2910
#
#                              18_cases_per1k  \
# 0                                    4.1974
# 1                                    2.1716
# 5                                    2.8754
# 13                                   4.1097
# 16                                   2.7759
#
#                            increase_percent  total_budget  clean_air  \
# 0                                   22.2301        139000      21000
# 1                                   37.1607        220000      50000
# 5                                   25.5164        199000      72000
# 13                                  12.8768        239000      42000
# 16                                  40.8987        290000      32000
#
#     clean_environ  health_training  school_awareness  media_awareness  \
# 0           22000            18000             41000            18000
# 1           17000            23000             74000            30000
# 5           27000            14000             64000            15000
# 13          72000            22000             48000            39000
# 16          80000            22000             63000            59000
#
#     sub_counselling
# 0             19000
# 1             26000
# 5              7000
# 13            16000
# 16            34000

# %%
#x_values = london_data[['clean_environ_p','health_training_p',
#                        'school_awareness_p','media_awareness_p','sub_counselling_p']]



london_data_numeric.head()




x_values = london_data_numeric.drop(['oeight_cases_per1k','13_cases_per1k','18_cases_per1k',
                                    'increase_percent','total_budget'],axis=1)
x_values_vif = drop_column_using_vif_(x_values)

model = sms.OLS(endog=london_data[['increase_percent']], exog=sms.add_constant(x_values)).fit()
model.summary()
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Dropping: clean_air
# Dropping: clean_environ
# Dropping: health_training
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Dropping: school_awareness
# Dropping: media_awareness
# Dropping: sub_counselling
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1729: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       increase_percent   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):                nan
# Time:                        13:48:59   Log-Likelihood:                 684.37
# No. Observations:                  33   AIC:                            -1303.
# Df Residuals:                       0   BIC:                            -1253.
# Df Model:                          32
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           1.4902        inf          0        nan         nan         nan
# clean_air                                       0.0003        inf          0        nan         nan         nan
# clean_environ                                6.264e-05        inf          0        nan         nan         nan
# health_training                                 0.0003        inf          0        nan         nan         nan
# school_awareness                               -0.0001        inf         -0        nan         nan         nan
# media_awareness                                 0.0004        inf          0        nan         nan         nan
# sub_counselling                                 0.0003        inf          0        nan         nan         nan
# local_authority_area_Barking and Dagenham       1.0328        inf          0        nan         nan         nan
# local_authority_area_Barnet                     4.8908        inf          0        nan         nan         nan
# local_authority_area_Bexley                     0.3903        inf          0        nan         nan         nan
# local_authority_area_Brent                    -23.9116        inf         -0        nan         nan         nan
# local_authority_area_Bromley                   -5.5754        inf         -0        nan         nan         nan
# local_authority_area_Camden                    -2.2576        inf         -0        nan         nan         nan
# local_authority_area_Croydon                    3.9070        inf          0        nan         nan         nan
# local_authority_area_Ealing                   -14.5056        inf         -0        nan         nan         nan
# local_authority_area_Enfield                   -5.5258        inf         -0        nan         nan         nan
# local_authority_area_Greenwich                  6.4233        inf          0        nan         nan         nan
# local_authority_area_Hackney                    0.1583        inf          0        nan         nan         nan
# local_authority_area_Hammersmith and Fulham    -5.6659        inf         -0        nan         nan         nan
# local_authority_area_Haringey                  -7.4606        inf         -0        nan         nan         nan
# local_authority_area_Harrow                    -1.7126        inf         -0        nan         nan         nan
# local_authority_area_Havering                  -7.6281        inf         -0        nan         nan         nan
# local_authority_area_Hillingdon                -1.7820        inf         -0        nan         nan         nan
# local_authority_area_Hounslow                  -3.6048        inf         -0        nan         nan         nan
# local_authority_area_Islington                  5.4573        inf          0        nan         nan         nan
# local_authority_area_Kensington and Chelsea    25.2483        inf          0        nan         nan         nan
# local_authority_area_Kingston upon Thames      21.8402        inf          0        nan         nan         nan
# local_authority_area_Lambeth                  -19.8512        inf         -0        nan         nan         nan
# local_authority_area_Lewisham                  11.5612        inf          0        nan         nan         nan
# local_authority_area_Merton                    18.1074        inf          0        nan         nan         nan
# local_authority_area_Newham                    -0.2248        inf         -0        nan         nan         nan
# local_authority_area_Redbridge                 11.2359        inf          0        nan         nan         nan
# local_authority_area_Richmond upon Thames      47.5788        inf          0        nan         nan         nan
# local_authority_area_Southwark                 -3.4534        inf         -0        nan         nan         nan
# local_authority_area_Sutton                    13.4688        inf          0        nan         nan         nan
# local_authority_area_Tower Hamlets              0.3750        inf          0        nan         nan         nan
# local_authority_area_Waltham Forest             2.4582        inf          0        nan         nan         nan
# local_authority_area_Wandsworth                -2.4357        inf         -0        nan         nan         nan
# local_authority_area_Westminster                6.9207        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.651   Durbin-Watson:                   0.540
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.549
# Skew:                           0.460   Prob(JB):                        0.461
# Kurtosis:                       2.472   Cond. No.                     1.05e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 1.05e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# plot 
plt.scatter(model.fittedvalues, model.resid)
# adding title and labels
plt.xlabel('Fitted ')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot ')
plt.show()

# %%
# The data file must be in columns of numbers - no column labels, etc.
# The first column is the y values, the following columns are the predictors x1, x2, x3, etc.

# This data must be saved as a csv file (e.g. use "Save As" in Excel and choose csv format).
# It must be saved in the same folder as this program.
# See the file demo_multreg_data_example.csv for reference.

# In the next line, replace demo_multreg_data_example.csv with the filename of your data:
data_filename = 'demo_multreg_data_example.csv'


# These lines extract the y-values and the x-values from the data:
y_values = data[:,0]
x_values = data[:,1:]

# These lines perform the regression procedure:
X_values = sms.add_constant(x_values)
regression_model_a = sms.OLS(y_values, X_values)
regression_model_b = regression_model_a.fit()
# and print a summary of the results:
print(regression_model_b.summary())
print() # blank line

# Now we store all the relevant values:
predictor_coeffs  = regression_model_b.params[1:]
constant          = regression_model_b.params[0] # called the 'intercept' in simple regression
Rsquared          = regression_model_b.rsquared
MSE               = regression_model_b.mse_resid
pvalues_T         = regression_model_b.pvalues[1:]
pvalue_F          = regression_model_b.f_pvalue

# Note that predictor_coeffs is a list of the best-fit coefficients for x1, x2, x3, ...
# Similarly, pvalues_T is a list of the p-values associated with each of these variables in turn.

# Print these summary stats:
print("predictor coefficients =", predictor_coeffs)
print("constant               =", constant)
print("Rsquared               =", Rsquared)
print("MSE                    =", MSE)
print("T-test pvalues         =", pvalues_T)
print("F-test pvalue          =", pvalue_F)
